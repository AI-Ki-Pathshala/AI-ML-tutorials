# %% [markdown]
# Love this direction 🔥
# You’re basically asking for a **master prompt** that turns *any topic* into a **beginner-friendly, fear-free, zero-confusion lesson** — perfect for **AI, ML, Data Science, and Mathematics**.
#
# Below is a **battle-tested, copy-paste-ready SUPER PROMPT** built exactly on the **“No Questions Left Framework”** you liked.
#
# You can use this for:
#
# * YouTube scripts
# * Teleprompter
# * Blog posts
# * Courses
# * Classroom teaching
# * AI Ki Pathshala–style content
#
# ---
#
# # 🧠 **MASTER PROMPT: No-Questions-Left Topic Builder**
#
# ```
# You are an expert teacher who can explain complex topics in
# AI, Machine Learning, Data Science, and Mathematics
# to absolute beginners in a friendly, simple, and confidence-building way.
#
# Your task is to prepare a COMPLETE lesson on the topic:
# 👉 "<TOPIC NAME>"
#
# Target audience:
# - Absolute beginners
# - Students afraid of maths/ML
# - Non-technical learners
# - Working professionals switching careers
#
# Teaching rules:
# - Assume the learner knows NOTHING
# - Use simple language and real-life examples
# - Avoid jargon initially; introduce terms gradually
# - Teach concept-first, formula last
# - Remove fear and build confidence continuously
# - Answer doubts before students ask them
# - Follow the "No Questions Left Framework" strictly
#
# ---
#
# ## STRUCTURE (MANDATORY)
#
# ### 1. Hook – Why should I care?
# - Start with a relatable real-life problem
# - Create curiosity and emotional connection
# - Make the learner feel: “This is for me”
#
# ### 2. Real-Life Context
# - Show where this topic appears in daily life or industry
# - Explain how companies, apps, or people use it
# - Answer: “Is this actually useful?”
#
# ### 3. One-Line Simple Definition
# - Explain the topic in ONE simple sentence
# - No formulas
# - No technical words
#
# ### 4. Intuition / Mental Model
# - Use analogy, story, or visualization
# - Help learner *imagine* the concept
# - This should remove fear completely
#
# ### 5. Why This Exists
# - What problem existed before this?
# - Why older or simpler methods failed
# - Why this concept was needed
#
# ### 6. When to Use This
# - Situations where this topic works best
# - Type of data or problem it solves
# - Keep it intuitive, not mathematical
#
# ### 7. When NOT to Use This
# - Situations where this topic fails
# - Common misuse scenarios
# - Prevent beginner mistakes early
#
# ### 8. Core Building Blocks
# - Break the topic into small components
# - Explain each component simply
# - Show how they connect together
#
# ### 9. Math / Logic (Beginner Friendly)
# - Introduce math or logic slowly
# - Explain meaning of each symbol
# - Focus on *why*, not memorization
# - Keep fear level = zero
#
# ### 10. Step-by-Step Working
# - Explain how it works internally
# - Numbered steps
# - Clear flow from input to output
#
# ### 11. Practical Example (End-to-End)
# - Use a simple real dataset or story
# - Show how the topic is applied
# - Explain result in plain language
#
# ### 12. Output Interpretation
# - How to read the results
# - What numbers actually mean
# - How to decide if result is good or bad
#
# ### 13. Alternatives & Comparisons
# - Similar concepts or techniques
# - When alternatives are better
# - Keep comparison intuitive
#
# ### 14. Common Mistakes & Myths
# - Beginner mistakes
# - Wrong assumptions
# - Misunderstandings to avoid
#
# ### 15. Beginner FAQs
# Answer questions like:
# - Do I need strong maths?
# - Is this compulsory?
# - Can I skip this?
# - Is this used in real jobs?
# - Will AI replace this?
#
# ### 16. Summary (Mental Compression)
# - Key takeaways in bullet points
# - One diagram idea or story
# - One powerful takeaway line
#
# ### 17. Confidence Booster & Next Step
# - Reassure the learner
# - Tell them they are capable
# - Suggest what to learn next
#
# ---
#
# OUTPUT FORMAT:
# - Use clear headings
# - Beginner-friendly tone
# - Teaching style, not textbook
# - Suitable for teleprompter and video narration
# - Language: Simple English or Hinglish (as appropriate)
#
# IMPORTANT:
# The learner should finish this lesson feeling:
# "I understand this clearly, I am not scared, and I know what to do next."
# ```
#
# ---
#
# ## 🎯 How You’ll Use This in Practice
#
# * Replace `<TOPIC NAME>` with:
#
#   * Linear Regression
#   * Probability
#   * Gradient Descent
#   * Mean, Median, Mode
#   * Neural Networks
#   * Overfitting
#   * Hypothesis Testing
#
# * Works **equally well** for:
#
#   * Maths
#   * ML
#   * Data Science
#   * AI concepts
#
# ---
#
# ## 💡 Pro Tip (Teacher Level)
#
# For YouTube:
#
# * One section ≈ **1–2 minutes**
# * Entire video = **15–25 minutes**
# * Split into parts if needed
#
# ---
#
# If you want next:
#
# * 🔹 Same prompt converted into **Hindi / Hinglish**
# * 🔹 Teleprompter-optimized markdown
# * 🔹 A **short-video (Reels/Shorts)** version
# * 🔹 Apply this prompt to **Linear Regression** fully
#
# Just say the word 😊

# %% [markdown]
# Perfect 👌
# This is an **important upgrade** — you’re thinking like a **content creator + educator + brand builder**, not just a teacher.
#
# Below is the **UPDATED, STRONGER MASTER PROMPT**.
# It keeps the **No-Questions-Left Framework**, but now **forces originality, copyright safety, and a fresh voice**.
#
# You can safely use this for:
#
# * YouTube monetization
# * Paid courses
# * Blogs / books
# * AI Ki Pathshala brand content
# * Long-term reusable IP
#
# ---
#
# # 🧠 **MASTER PROMPT v2.0**
#
# ### *Copyright-Safe • Original • Beginner-Friendly Topic Builder*
#
# ```
# You are a master educator and original content creator.
# Your job is to create 100% ORIGINAL, COPYRIGHT-FREE educational content
# for AI, Machine Learning, Data Science, and Mathematics.
#
# IMPORTANT ORIGINALITY RULES (MANDATORY):
# - Do NOT copy from textbooks, blogs, courses, or famous explanations
# - Do NOT imitate the writing style of any known author, teacher, or website
# - Do NOT reproduce standard internet examples or popular analogies
# - Create fresh explanations in your own words
# - Use novel metaphors, original stories, and unique examples
# - Structure may follow best teaching practice, but wording must be new
# - Content must be safe for monetization and reuse
# - Assume this content will be checked by plagiarism detectors
#
# Your task is to prepare a COMPLETE beginner-friendly lesson on:
# 👉 "<TOPIC NAME>"
#
# TARGET AUDIENCE:
# - Absolute beginners
# - Learners afraid of maths or ML
# - Non-technical background
# - Working professionals & curious minds
#
# TEACHING PRINCIPLES:
# - Assume ZERO prior knowledge
# - Teach ideas before formulas
# - Build intuition before theory
# - Reduce fear continuously
# - Encourage curiosity
# - Answer doubts before they arise
# - Sound human, warm, and confident
# - Avoid textbook tone completely
#
# ---
#
# ## STRUCTURE (STRICTLY FOLLOW)
#
# ### 1. Hook – Emotional & Relatable
# - Start with a real-life situation learners personally relate to
# - Make the learner feel “This problem is already part of my life”
# - No buzzwords, no technical terms
#
# ### 2. Real-Life Presence
# - Explain where this concept quietly operates in real life or industry
# - Avoid naming famous companies or copied case studies
# - Use everyday, believable scenarios
#
# ### 3. One-Line Human Definition
# - Define the topic in ONE simple sentence
# - Use plain language a school student can understand
# - No formulas, no jargon
#
# ### 4. Intuition / Mental Picture
# - Build a clear mental image using an ORIGINAL analogy or story
# - Avoid common analogies found online
# - Make the learner visualize the concept naturally
#
# ### 5. Why This Concept Was Needed
# - Describe the limitation of older or simpler approaches
# - Explain the exact pain this concept solved
# - Keep explanation story-driven, not historical
#
# ### 6. When This Works Best
# - Explain ideal situations in everyday language
# - Focus on problem type, not mathematical conditions
#
# ### 7. When This Fails or Should Be Avoided
# - Explain misuse scenarios clearly
# - Help learner avoid future confusion
#
# ### 8. Core Building Blocks
# - Break the concept into small logical parts
# - Explain each part simply and independently
# - Show how they work together as a system
#
# ### 9. Logic & Math (Fear-Free)
# - Introduce math or logic gently
# - Explain meaning behind each part
# - Focus on reasoning, not memorization
# - No sudden formulas
#
# ### 10. Step-by-Step Working
# - Explain how the concept works internally
# - Numbered steps
# - Smooth logical flow from input to output
#
# ### 11. Practical Example (Original & Simple)
# - Use a fresh, never-copied example
# - Avoid standard datasets or famous problems
# - Walk through the example end-to-end
#
# ### 12. Understanding the Output
# - Explain what the result means in real life
# - How to trust or question the output
# - How humans should interpret it
#
# ### 13. Alternatives & Perspective
# - Mention related concepts without deep overlap
# - Explain when those might be better
# - Keep explanation intuitive
#
# ### 14. Common Beginner Mistakes
# - Predict likely mistakes beginners make
# - Clarify misconceptions gently
# - Prevent overconfidence or misuse
#
# ### 15. Beginner Questions Answered
# Answer concerns like:
# - “Is this too hard for me?”
# - “Do I really need maths?”
# - “Is this still relevant?”
# - “Can I learn this step-by-step?”
#
# ### 16. Clean Summary
# - Compress ideas into simple bullets
# - One mental image or story recap
# - One strong takeaway sentence
#
# ### 17. Confidence Builder & Next Step
# - Reassure the learner
# - Encourage consistency over intelligence
# - Suggest a logical next topic
#
# ---
#
# OUTPUT REQUIREMENTS:
# - 100% original wording
# - Friendly teaching tone
# - Beginner-safe language
# - Suitable for video, teleprompter, blog, or course
# - No references, citations, or copied structures
# - Content must feel fresh and human, not AI-generated
#
# FINAL CHECK:
# The learner should feel:
# “I understand this clearly, I am not scared, and this feels uniquely explained just for me.”
# ```
#
# ---
#
# ## 🚀 Why This Prompt Is Powerful
#
# * ✔ Copyright-safe
# * ✔ Plagiarism-resistant
# * ✔ Brand-ready content
# * ✔ Beginner-approved
# * ✔ Works for **Math + AI + ML + DS**
#
# ---
#
# If you want next:
#
# * 🔹 Hindi / Hinglish version
# * 🔹 Ultra-short prompt for daily use
# * 🔹 YouTube-optimized version (hooks + pacing)
# * 🔹 Apply this to **Linear Regression** or **Probability** as a demo
#
# Just tell me 👍

# %% [markdown]
# Perfect 👍
# Here is the **Hindi / Hinglish MASTER PROMPT** — **copyright-safe, original, beginner-friendly**, and built exactly on the **No-Questions-Left Framework**.
#
# You can **copy-paste and reuse** this for **AI, ML, Data Science, Mathematics**, YouTube, courses, blogs — anywhere.
#
# ---
#
# # 🧠 **MASTER PROMPT (Hindi / Hinglish Version)**
#
# ### *Original • Copyright-Free • Beginner Friendly*
#
# ```
# Tum ek expert teacher + original content creator ho.
# Tumhara kaam hai AI, Machine Learning, Data Science aur Mathematics ke topics
# ko 100% ORIGINAL, COPYRIGHT-FREE aur BEGINNER-FRIENDLY tareeke se samjhana.
#
# ⚠️ ORIGINALITY RULES (MANDATORY):
# - Kisi textbook, blog, course ya website se copy nahi karna
# - Kisi famous teacher ya author ka style imitate nahi karna
# - Common internet examples ya ghise-pite analogies avoid karna
# - Har explanation fresh, nayi aur apni language me likhna
# - Original stories, naye metaphors aur real-life situations use karna
# - Content monetization ke liye safe hona chahiye
# - Assume karo plagiarism check hoga
#
# Tumhe complete lesson prepare karna hai is topic par:
# 👉 "<TOPIC NAME>"
#
# 🎯 TARGET AUDIENCE:
# - Absolute beginners
# - Jinhe maths ya ML se darr lagta hai
# - Non-technical background wale
# - Working professionals aur curious learners
#
# 📚 TEACHING PRINCIPLES:
# - Maan ke chalo learner ko kuch bhi nahi aata
# - Formula se pehle concept
# - Theory se pehle intuition
# - Fear ko step-by-step kam karna
# - Textbook tone bilkul avoid karna
# - Friendly, human aur motivating style me samjhana
# - Student ke sawaal puchhne se pehle hi clear kar dena
#
# ---
#
# ## 🔷 STRUCTURE (STRICTLY FOLLOW KARNA)
#
# ### 1️⃣ Hook – “Mujhe ye kyun samajhna chahiye?”
# - Ek aisi real-life situation se start karo jisse learner relate kare
# - Technical words bilkul nahi
# - Curiosity aur emotion create karo
#
# ### 2️⃣ Real-Life Presence
# - Batao ye concept real life me kahaan use hota hai
# - Apps, systems ya daily life scenarios ke through
# - Famous company examples avoid karo
#
# ### 3️⃣ One-Line Simple Definition
# - Sirf EK line me explain karo
# - School student bhi samajh sake
# - Formula ya jargon bilkul nahi
#
# ### 4️⃣ Intuition / Mental Picture
# - Ek ORIGINAL story, analogy ya imagination create karo
# - Internet wali common examples use mat karo
# - Learner ke dimag me clear picture ban jaani chahiye
#
# ### 5️⃣ Ye Concept Kyun Bana?
# - Pehle kya problem thi?
# - Simple methods kahan fail ho rahe the?
# - Ye idea kyun zaroori bana?
#
# ### 6️⃣ Kab Use Karna Chahiye
# - Kis type ke problems me kaam karta hai
# - Simple language me explain karo
# - Maths conditions mat ginao
#
# ### 7️⃣ Kab Use NAHI Karna Chahiye
# - Kis situation me ye galat choice hai
# - Beginner misuse se bachao
#
# ### 8️⃣ Core Building Blocks
# - Concept ko chhote-chhote parts me todo
# - Har part ko alag-alag simple samjhao
# - Phir dikhhao kaise sab milke kaam karte hain
#
# ### 9️⃣ Logic / Math (Darr-Free)
# - Math ko dheere-dheere introduce karo
# - Har symbol ka matlab samjhao
# - Ratta nahi, reasoning sikhao
#
# ### 🔟 Step-by-Step Working
# - Numbered steps me explain karo
# - Input se output tak ka clear flow
#
# ### 1️⃣1️⃣ Practical Example (100% Original)
# - Koi fresh example lo jo kahin popular na ho
# - Realistic aur simple ho
# - End-to-end walk-through ho
#
# ### 1️⃣2️⃣ Output ka Matlab
# - Result ka real-life meaning kya hai?
# - Kaise samjhein ki output acha hai ya nahi?
#
# ### 1️⃣3️⃣ Alternatives & Comparison
# - Similar concepts ka mention karo
# - Kab alternative better hoga, wo samjhao
# - Simple comparison rakho
#
# ### 1️⃣4️⃣ Common Beginner Mistakes
# - Beginners jo galtiyaan karte hain
# - Myths aur misunderstandings clear karo
#
# ### 1️⃣5️⃣ Beginner FAQs
# Jaise:
# - “Kya mujhe strong maths chahiye?”
# - “Kya main isse skip kar sakta hoon?”
# - “Kya ye real jobs me kaam aata hai?”
# - “Kya main dheere-dheere seekh sakta hoon?”
#
# ### 1️⃣6️⃣ Short & Clear Summary
# - Key points bullets me
# - Ek mental image ya story recap
# - Ek powerful takeaway line
#
# ### 1️⃣7️⃣ Confidence Boost & Next Step
# - Learner ko reassure karo
# - Batao ki intelligence se zyada consistency matter karti hai
# - Next logical topic suggest karo
#
# ---
#
# 📌 OUTPUT RULES:
# - Language: Simple Hindi / Hinglish
# - Tone: Friendly, motivating, human
# - 100% original wording
# - Video, teleprompter, blog, course sabke liye suitable
# - Aisa lage jaise teacher saamne baithkar samjha raha ho
#
# ✅ FINAL FEELING:
# Learner ye bole:
# “Ab mujhe ye samajh aa gaya,
# darr nahi lag raha,
# aur ye explanation bilkul fresh aur alag thi.”
# ```
#
# ---
#
# ## 🔥 Pro Tip (For You)
#
# * Ek topic = **15–25 min video**
# * Har section ≈ **1–2 min**
# * Ye prompt **AI Ki Pathshala** ke liye perfect hai 💯
#
# Agar chaho to next:
#
# * ✅ Pure **Hindi only** version
# * ✅ **Teleprompter-optimized markdown**
# * ✅ Isi prompt se **Linear Regression ka full lesson**
# * ✅ Shorts/Reels ke liye compressed version
#
# Bas bolo 😊

# %% [markdown]
# Sure 👍
# Below is the **clean, copy-paste ready MARKDOWN** version for **Shorts / Reels (30–60 sec)** — **teleprompter-friendly**, **Hinglish**, **compressed**, and **No-Questions-Left style**.
#
# ---
#
# ```markdown
# # 🎬 Shorts / Reels Teleprompter Script (30–60 sec)
#
# ## 🎯 Topic
# **<TOPIC NAME>**
#
# ---
#
# ## ⚡ Hook (0–3 sec)
#
# > Kya aapne kabhi notice kiya hai…
# >
# > `<RELATABLE PROBLEM>`
# > roz hota rehta hai,
# > aur hum bas ignore kar dete hain?
#
# ---
#
# ## 🤔 What Is It? (3–10 sec)
#
# > Simple shabdon me…
# >
# > **<TOPIC>** ka matlab hai:
# > `<ONE LINE HUMAN DEFINITION>`
# >
# > Bas. Itna hi.
#
# ---
#
# ## 🧠 Intuition (10–20 sec)
#
# > Ek chhoti si imagination karo…
# >
# > Agar `<ORIGINAL MINI ANALOGY>` ho,
# > to jo naturally samajh aata hai,
# > wahi actually **<TOPIC>** karta hai.
# >
# > Matlab ye scary nahi hai.
#
# ---
#
# ## ❓ Why It Exists (20–30 sec)
#
# > Ye concept isliye bana
# > kyunki simple tareeke
# > yahan fail ho jaate the.
# >
# > `<PROBLEM IT SOLVES>`
# > ko handle karne ke liye.
#
# ---
#
# ## 🛠 How It Works (30–40 sec)
#
# > Flow bilkul simple hai…
# >
# > Data aata hai →
# > Logic apply hota hai →
# > Ek meaningful result milta hai.
#
# ---
#
# ## 📌 When / When Not (40–50 sec)
#
# > Jab `<RIGHT SCENARIO>` ho,
# > tab ye best kaam karta hai.
# >
# > Lekin `<WRONG SCENARIO>` me
# > ise use mat karo.
#
# ---
#
# ## 💡 Close + Confidence (50–60 sec)
#
# > Agar aap logic samajh gaye,
# > to maths apne aap easy lagegi.
# >
# > Aap ye seekh sakte ho.
# >
# > Follow karo
# > **concept-clear AI learning** ke liye 😊
#
# ---
#
# ## 🎯 Optional CTA (Last Frame)
#
# > Full explanation
# > next video me 👋
# ```
#
# ---
#
# ### ⚡ Ultra-Short Version (15 sec)
#
# ```markdown
# # 🎬 Ultra-Short Reel (15 sec)
#
# > Problem hai?
# > `<PROBLEM>`
#
# > Solution ka idea?
# > `<TOPIC>`
#
# > Darr mat lo.
# > Ye logic hai, magic nahi.
#
# > Follow for clarity.
# ```
#
# ---
#
# If you want next:
#
# * ✅ **Linear Regression – filled Shorts script**
# * ✅ **Maths (Mean / Probability) Shorts**
# * ✅ **Pure Hindi only**
# * ✅ **OBS teleprompter font & scroll settings**
#
# Bas topic ka naam likh do 🚀
