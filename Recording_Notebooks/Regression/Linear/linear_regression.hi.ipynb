# %% [markdown]
# <a href="https://colab.research.google.com/github/AI-Ki-Pathshala/AI-ML-tutorials/blob/main/Recording_Notebooks/Regression/Linear/linear_regression.hi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://github.com/AI-Ki-Pathshala/AI-ML-tutorials/blob/main/Recording_Notebooks/Images/chai_ki_dukan.png?raw=1" style="width:100%;"/>

# %% [markdown]
# <a href="https://colab.research.google.com/github/AI-Ki-Pathshala/AI-ML-tutorials/blob/main/Recording_Notebooks/Regression/1_Linear_Regression_Hindi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# region
import os
import sys
import pandas as pd

def load_csv(
    filename,
    github_raw_url=None,
    local_path="data"
):
    """
    Common data loader for:
    - VS Code (local)
    - Google Colab
    """

    # 1️⃣ Detect Colab
    running_in_colab = 'google.colab' in sys.modules

    # 2️⃣ If file exists locally → use it
    local_file = os.path.join(local_path, filename)
    if os.path.exists(local_file):
        print("📁 Loading from local file system")
        return pd.read_csv(local_file)

    # 3️⃣ If running in Colab & GitHub URL provided
    if running_in_colab and github_raw_url:
        print("🌐 Loading from GitHub (Colab)")
        return pd.read_csv(github_raw_url)

    # 4️⃣ Nothing worked
    raise FileNotFoundError(
        "❌ Data file not found locally and no GitHub URL provided."
    )

def load_data(filename, github_raw_url=None, local_path="data"):
    ext = filename.split(".")[-1]

    local_file = os.path.join(local_path, filename)

    if os.path.exists(local_file):
        print("📁 Local file detected")
        path = local_file
    elif 'google.colab' in sys.modules and github_raw_url:
        print("🌐 Loading from GitHub")
        path = github_raw_url
    else:
        raise FileNotFoundError("File not found")

    if ext == "csv":
        return pd.read_csv(path)
    elif ext in ["xlsx", "xls"]:
        return pd.read_excel(path)
    else:
        raise ValueError("Unsupported file format")


# endregion

# %% [markdown]
# मान लीजिए आप एक चाय की दुकान चला रहे हैं ☕
# आपने ये बातें नोट कीं:
#
# | घंटा | कमाई |
# |--------|-------
# | 0      | ₹0
# | 1      | ₹50
# | 2      | ₹100
# | 3      | ₹150
# | 4      | ?

# %%
# region Plot data on the graph.
import matplotlib.pyplot as plt

# Time (hours)
x = [1, 2, 3, 4]

# Money earned
y = [50, 100, 150, 200]

plt.scatter(x, y)
plt.plot(x, y)
plt.xlabel("Time (hours)")
plt.ylabel("Money (₹)")
plt.title("Time vs Money")
plt.show()
# endregion

# %% [markdown]
# अब हम 4 घंटे काम कराने के बाद दुकानदार कितनी कमाई करेगा, यह निकालते हैं।
#
# **अंतर निकालिए:**
# - 50 − 0 = 50
# - 100 − 50 = 50
# - 150 − 100 = 50
# - ? − 150 = 50
#
# **Observation:**
# हर घंटे कमाई ₹50 बढ़ रही है।
#
# **Calculation:**
# 150 + 50 = **200**
#
# **Answer:**
# 4 ghante ki kamai = **₹200**
#
# ---------------------------------------
# अब इसी पैटर्न को फ़ॉर्मूला में बदलते हैं
# ---------------------------------------
#
# | घंटा (x) | कमाई (y) | प्रति घंटे की कमाई / Rate of Change (m)  | शुरुआती बिंदु /0 घंटे पर कमाई/ Starting Point (c) |
# |------------|-----------|-------------------|--------------------|
# | 0          | 0         | 50                | 0                  |
# | 1          | 50        | 50                | 0                  |
# | 2          | 100       | 50                | 0                  |
# | 3          | 150       | 50                | 0                  |
# | 4          | ?         | 50                | 0                  |
#
# **मतलब - Meaning:**
# - m = 50 (प्रति घंटे की कमाई)
# - c = 0 (0 घंटे पर कमाई 0)
#
# **(फ़ॉर्मूला समझ में आया) - Formula discover hui -:**
# y = mx + c
# y = 50x + 0
#
# **(अनुमान) - Prediction :**
# y = 50 × 4 = **200**

# %% [markdown]
# ---------------------------------------
# AI + MACHINE LEARNING CODING
# -----------------------------------------

# %%
# region Import Linear Regression model from sklearn library
from sklearn.linear_model import LinearRegression

# Training data (input)
# X represents time (hours)
# Double brackets are used because ML models expect 2D data
X = [[1], [2], [3], [4]]

# Training data (output)
# y represents money earned at each hour
y = [50, 100, 150, 200]

# Create a Linear Regression model object
model = LinearRegression()

# Train the model using input (X) and output (y)
# Model learns the relationship between time and money
model.fit(X, y)

# Predict money for future time = 5 hours
# Again using double brackets to keep input 2D
print(model.predict([[5]]))

print("Slope (m):", model.coef_)
print("Intercept (c):", model.intercept_)

print(f"formula : y = {model.coef_}x+{model.intercept_}")
# endregion

# %% [markdown]
# ------------------------
# 📌 Examples
# ------------------------
# Gaadi accelerate kar rahi hai (speed har second zyada tez badh rahi hai).
#
# | Time (seconds) | Speed (km/h) |
# |----------------|-------------|
# | 1              | 2           |
# | 2              | 8           |
# | 3              | 18          |
# | 4              | 32          |
# | 5              | 50          |
# | 6              | 72          |

# %%
# region Import matplotlib library for drawing graphs
import matplotlib.pyplot as plt

# Time values (in seconds)
time = [1, 2, 3, 4, 5, 6]

# Speed values corresponding to each time
speed = [2, 8, 18, 32, 50, 72]

# Draw dots to show actual data points
plt.scatter(time, speed)

# Draw a line connecting the points
plt.plot(time, speed)

# Label for X-axis (time)
plt.xlabel("Time (seconds)")

# Label for Y-axis (speed)
plt.ylabel("Speed (km/h)")

# Title of the graph
plt.title("Speed vs Time (Acceleration – Not Linear)")

# Display the graph on screen
plt.show()
# endregion

# %%
# region Crop Production (फसलों का उत्पादन): क्यों Linear Regression यहाँ काम नहीं करती?
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load dataset
git_path = r"https://raw.githubusercontent.com/AI-Ki-Pathshala/AI-ML-tutorials/refs/heads/main/Recording_Notebooks/Regression/Linear/Data/Crop_Production_Bad_Example.csv"
df = load_data('Crop_Production_Bad_Example.csv',git_path,r'Data/')
# file_path = r'Data/Crop_Production_Bad_Example.csv'
# df = pd.read_csv(file_path)

# Columns example: Crop_Year, Production
df = df.dropna()
X = df[['Crop_Year']]
y = df['Production']

# Train model
model = LinearRegression()
model.fit(X, y)

# Prediction
y_pred = model.predict(X)

# Plot
plt.figure()
plt.scatter(X, y)
plt.plot(X, y_pred)
plt.xlabel("Year")
plt.ylabel("Crop Production")
plt.title("BAD Example: Linear Regression Fails")
plt.show()
# endregion
# Out:
# 📁 Local file detected

# %%
# region House Price : क्यों Linear Regression यहाँ काम करती?
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load dataset
git_path = r"https://raw.githubusercontent.com/AI-Ki-Pathshala/AI-ML-tutorials/main/Recording_Notebooks/Regression/Linear/Data/House_Price_India_Good_Example.csv"
df = load_data('House_Price_India_Good_Example.csv',git_path,r'Data/')
# file_path = r'Data/House_Price_India_Good_Example.csv'
# df = pd.read_csv(file_path)

# Clean column names (VERY IMPORTANT)
df.columns = df.columns.str.strip()

# Check NaN values
# print("NaN count before cleaning:")
# print(df[['living area', 'Price']].isna().sum())

# Remove NaN rows
df = df[['living area', 'Price']].dropna()

# Define X and y
X = df[['living area']]   # Independent variable
y = df['Price']           # Dependent variable

# Train model
model = LinearRegression()
model.fit(X, y)

# Predict
y_pred = model.predict(X)

# Plot
plt.figure()
plt.scatter(X, y)
plt.plot(X, y_pred)
plt.xlabel("Living Area (sq ft)")
plt.ylabel("House Price")
plt.title("GOOD Example: Linear Regression (Living Area vs Price)")
plt.show()
# endregion
# Out:
# 📁 Local file detected

# %%
# region Salary Prediction : क्यों Linear Regression यहाँ काम करती?
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load dataset
git_path = r"https://raw.githubusercontent.com/AI-Ki-Pathshala/AI-ML-tutorials/main/Recording_Notebooks/Regression/Linear/Data/Salary_dataset_Good_Example.csv"
df = load_data('Salary_dataset_Good_Example.csv',git_path,r'Data/')
# file_path = r'Data/Salary_dataset_Good_Example.csv'
# df = pd.read_csv(file_path)

# Step 2: Define X (input) and y (output)
X = df[["YearsExperience"]]   # must be 2D
y = df["Salary"]

# Step 3: Train Linear Regression model
model = LinearRegression()
model.fit(X, y)

# Step 4: Predict salaries
# Uses trained model to predict salary.
# Stores predictions in a new column:
# PredictedSalary
df["PredictedSalary"] = model.predict(X)

# # Step 5: Print predictions
# print(df)

# Step 6: Plot
# Draws dots for actual data points.
# Shows real salary values.
plt.scatter(df["YearsExperience"], df["Salary"])
# Draws a straight line for predicted values.
# This is the regression line.
plt.plot(df["YearsExperience"], df["PredictedSalary"])
# Label for X-axis.
plt.xlabel("Years of Experience")
# Label for Y-axis.
plt.ylabel("Salary")
# Sets the graph title.
plt.title("Salary Prediction using Linear Regression")
# Displays the graph on screen.
plt.show()

# Predicts salary for 3.5 years experience.
# Output is an estimated salary.
# print(model.predict([[3.5]]))
# Out:
# 📁 Local file detected
