# %% [markdown]
# ### 🎬 Scene Name: 01_Hook
#
# **🎯 Scene Goal:**
# Create curiosity and excitement without fear.
#
# **🧠 Simple Explanation:**
# Today we’ll learn two tiny ideas that power AI.
# They are simple.
# You already use them in daily life.
#
# **🎨 Visual Idea (What to draw/show):**
# 📦 Box → 🔄 changing number
# 🔒 Box → fixed number
#
# **🗣️ Narration Script (Beginner-Safe):**
# AI looks scary… but its foundation is very small. Two ideas. Once you get them, AI math becomes easy.
#
# **🐍 Python Demo (Optional):**
# Not needed in this scene

# %% [markdown]
# ### 🎬 Scene Name: 02_Fear
#
# **🎯 Scene Goal:**
# Remove fear and self-doubt.
#
# **🧠 Simple Explanation:**
# Many people feel scared of math. That fear is normal.
#
# **🎨 Visual Idea (What to draw/show):**
# 😟 ➜ 😌
#
# **🗣️ Narration Script (Beginner-Safe):**
# If math scared you before, that’s okay. You only need clarity.
#
# **🐍 Python Demo (Optional):**
# Not needed in this scene

# %% [markdown]
# ### 🎬 Scene Name: 03_Problem
#
# **🎯 Scene Goal:**
# Show confusion without structure.
#
# **🧠 Simple Explanation:**
# If numbers keep changing randomly, AI gets confused.
#
# **🎨 Visual Idea (What to draw/show):**
# ❓ 5 → 9 → 2
#
# **🗣️ Narration Script (Beginner-Safe):**
# If everything changes, AI cannot learn.
#
# **🐍 Python Demo (Optional):**
# Not needed in this scene

# %% [markdown]
# ### 🎬 Scene Name: 04_Idea
#
# **🎯 Scene Goal:**
# Introduce core idea gently.
#
# **🧠 Simple Explanation:**
# Some values change. Some never change.
#
# **🎨 Visual Idea (What to draw/show):**
# 🔄 Box | 🔒 Box
#
# **🗣️ Narration Script (Beginner-Safe):**
# We separate values into changing and fixed ones.
#
# **🐍 Python Demo (Optional):**
# Not needed in this scene

# %% [markdown]
# ### 🎬 Scene Name: 05_Variable
#
# **🎯 Scene Goal:**
# Explain variable clearly.
#
# **🧠 Simple Explanation:**
# A variable is a value that can change.
#
# **🎨 Visual Idea (What to draw/show):**
# 📦 1 → 2 → 3
#
# **🗣️ Narration Script (Beginner-Safe):**
# Variables are changeable boxes.
#
# **🐍 Python Demo (Optional):**
# Not needed in this scene

# %% [markdown]
# ### 🎬 Scene Name: 06_Constant
#
# **🎯 Scene Goal:**
# Explain constant clearly.
#
# **🧠 Simple Explanation:**
# A constant never changes.
#
# **🎨 Visual Idea (What to draw/show):**
# 🔒 10
#
# **🗣️ Narration Script (Beginner-Safe):**
# Constants stay fixed.
#
# **🐍 Python Demo (Optional):**
# Not needed in this scene

# %% [markdown]
# ### 🎬 Scene Name: 07_Compare
#
# **🎯 Scene Goal:**
# Compare clearly.
#
# **🧠 Simple Explanation:**
# Variable changes. Constant doesn’t.
#
# **🎨 Visual Idea (What to draw/show):**
# 🔄 vs 🔒
#
# **🗣️ Narration Script (Beginner-Safe):**
# That’s the difference.
#
# **🐍 Python Demo (Optional):**
# Not needed in this scene

# %% [markdown]
# ### 🎬 Scene Name: 08_RealLife
#
# **🎯 Scene Goal:**
# Relate to daily life.
#
# **🧠 Simple Explanation:**
# Age changes, birth year doesn’t.
#
# **🎨 Visual Idea (What to draw/show):**
# 🎂 🔄 | 📅 🔒
#
# **🗣️ Narration Script (Beginner-Safe):**
# You already know this.
#
# **🐍 Python Demo (Optional):**
# Not needed in this scene

# %% [markdown]
# ### 🎬 Scene Name: 09_AIUse
#
# **🎯 Scene Goal:**
# Show AI relevance.
#
# **🧠 Simple Explanation:**
# AI learns with variables and rules with constants.
#
# **🎨 Visual Idea (What to draw/show):**
# 🤖 + 🔄 + 🔒
#
# **🗣️ Narration Script (Beginner-Safe):**
# Both are needed.
#
# **🐍 Python Demo (Optional):**
# Not needed in this scene

# %%
# Scene 10 Demo
score = 10
max_score = 100
score = 20
print(score, max_score)

# %% [markdown]
# ### 🎬 Scene Name: 11_VisualRecap
#
# **🎯 Scene Goal:**
# Visual reinforcement.
#
# **🧠 Simple Explanation:**
# Variables move. Constants stay.
#
# **🎨 Visual Idea (What to draw/show):**
# 🔄 ➜ ➜ | 🔒 ❌
#
# **🗣️ Narration Script (Beginner-Safe):**
# Moving vs fixed.
#
# **🐍 Python Demo (Optional):**
# Not needed in this scene

# %% [markdown]
# ### 🎬 Scene Name: 12_Summary
#
# **🎯 Scene Goal:**
# Summarize.
#
# **🧠 Simple Explanation:**
# Variables change. Constants don’t.
#
# **🎨 Visual Idea (What to draw/show):**
# ✅ 🔄 | ✅ 🔒
#
# **🗣️ Narration Script (Beginner-Safe):**
# This is the foundation of AI math.
#
# **🐍 Python Demo (Optional):**
# Not needed in this scene

# %% [markdown]
# ### 🎬 Scene Name: 13_Confidence
#
# **🎯 Scene Goal:**
# Build confidence.
#
# **🧠 Simple Explanation:**
# You understood AI math basics.
#
# **🎨 Visual Idea (What to draw/show):**
# 💪 I CAN DO THIS
#
# **🗣️ Narration Script (Beginner-Safe):**
# We will learn step by step.
#
# **🐍 Python Demo (Optional):**
# Not needed in this scene
