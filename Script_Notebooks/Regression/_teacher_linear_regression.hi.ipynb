# %% [markdown]
# <a href="https://colab.research.google.com/github/AI-Ki-Pathshala/AI-ML-tutorials/blob/main/Script_Notebooks/Regression/1_Linear_Regression_Hindi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# अगर आपको maths से डर लगता है,
# ⏸️
#
# अगर Machine Learning confusing लगती है,
# ⏸️
#
# या आप beginner हैं —
# ⏸️⏸️
#
# और फिर भी AI को
# समझ के सीखना चाहते हैं,
# रट्टा लगाकर नहीं —
# ⏸️⏸️
#
# तो ये video आपके लिए है।
# ⏸️⏸️
#
# और इसी confusion को
# आज हम बिल्कुल simple तरीके से clear करेंगे।
# ⏸️⏸️
#
# आज के इस video में
# हम समझेंगे —
# ⏸️
#
# **Linear Regression**,
# real-life example के साथ।
# ⏸️⏸️
#
# Video के end तक
# concept crystal clear हो जाएगा।

# %% [markdown]
# ----
# 🗣️ Exact Hook Line (Face-to-Camera)
#
# “अगर मैं आपसे कहूँ कि
# AI खुद से maths का formula बना लेती है,
# तो आप मानोगे?”
#
# “और अगर मैं ये भी कहूँ कि
# आपने वही formula
# आज इस video में खुद discover करना है,
# बिना heavy maths के?”
#
# “तो video skip मत करना…
# क्योंकि ये AI की सबसे strong foundation है —
# Linear Regression।”
#
# ⏱️ ~25 seconds

# %% [markdown]
# ----------------------------
# सबसे पहले हम एक real-world example से शुरुआत करेंगे,
# ताकि आपको साफ-साफ समझ आ जाए कि AI और Machine Learning में Linear Regression आखिर होता क्या है।
#
# फिर हम उसी example के ज़रिए ये समझेंगे कि
# ये problem Linear Regression से ही क्यों solve होगी,
# और क्यों इस तरह की problems के लिए ये सबसे best और reliable method माना जाता है।
#
# अब सवाल ये आता है कि
# हमें कैसे पता चलेगा कि हमारा data Linear Regression का है,
# या फिर कोई और pattern follow कर रहा है?
#
# इसके लिए हम data को graph पर plot करेंगे।
# Graph देखते ही हमें साफ दिखाई देगा कि
# data एक सीधी line बना रहा है या नहीं।
#
# अगर graph में data एक सीधी line की तरह behave करता है,
# तो हमें confirm हो जाता है कि
# यहाँ Linear Regression apply करना सही decision है।

# %% [markdown]
# ---

# %% [markdown]
# अब हम एक real-world problem statement लेते हैं,
# ताकि concept और भी clear हो जाए।
#
# मान लीजिए,
# आप एक चाय की दुकान चलाते हैं।
#
# अगर आप 1 घंटे काम करते हैं,
# तो आपकी कमाई होती है 50 रुपये।
# 2 घंटे काम करने पर कमाई होती है 100 रुपये,
# 3 घंटे पर 150 रुपये,
# और इसी तरह आगे बढ़ती जाती है।
#
# अब ज़रा इस data table को ध्यान से देखिए
# और सोचिए —
# आपको इसमें कौन-सा pattern नज़र आ रहा है?
#
# आप notice करेंगे कि
# हर घंटे आपकी कमाई 50 रुपये से बढ़ रही है।
# मतलब,
# जितना ज़्यादा समय आप काम कर रहे हैं,
# उतनी ज़्यादा कमाई हो रही है।
#
# अब इसी data को
# हम Python code की मदद से
# graph में convert करेंगे,
# ताकि इस pattern को
# और भी आसानी से समझा जा सके।
#
# अब आप सोच रहे होंगे —
# “जब data table देखकर ही समझ आ रहा है,
# तो graph बनाने की ज़रूरत क्यों?”
#
# और आपकी सोच बिल्कुल सही है 👍
# अगर data table छोटा है,
# तो उसे देखकर pattern समझना आसान होता है।
#
# लेकिन सोचिए,
# अगर इसी data table में
# लाखों या करोड़ों rows हों,
# तो क्या तब भी pattern समझना आसान होगा?
#
# नहीं।
#
# इसीलिए हम graph का इस्तेमाल करते हैं,
# क्योंकि graph में
# pattern एक नज़र में साफ दिख जाता है,
# और यही वजह है कि
# AI और Machine Learning में
# data को graph पर देखना
# इतना ज़्यादा important होता है।

# %% [markdown]
# ---
# 🗣️ Retention Line
#
# “एक second रुकिए…
# आगे जो मैं दिखाने वाला हूँ,
# वही reason है
# कि AI graph देखे बिना काम नहीं करती।”
#
# “अगर आप ये point miss कर गए,
# तो Linear Regression हमेशा confusing लगेगा।”

# %% [markdown]
# ---

# %% [markdown]
# अब हम
# X-axis पर time (घंटे)
# और Y-axis पर कमाई रख रहे हैं।
#
# जब हम इस data table को
# graph पर plot करते हैं,
# तो हमें साफ़ दिखाई देता है कि
# points मिलकर एक सीधी line बना रहे हैं।
#
# अब चलिए थोड़ा सा math लगाते हैं।
#
# मान लीजिए,
# हमें पता करना है कि
# 4 घंटे में कमाई कितनी होगी।
#
# तो calculation करने पर
# answer आता है — 200 रुपये।
#
# बहुत बढ़िया 👏
# ये तो आपने अपने दिमाग से ही predict कर लिया।
#
# लेकिन सोचिए,
# क्या हम हर बार
# ऐसे ही manually calculation करते रहेंगे
# हर prediction के लिए?
#
# नहीं।
#
# इसीलिए अब हम
# एक math का formula discover करते हैं,
# जो हर बार हमारे काम आए।
#
# अब ध्यान दीजिए —
# हर घंटे कमाई 50 रुपये बढ़ रही है।
#
# यानी कमाई के बढ़ने की speed
# या rate of change है 50 रुपये।
#
# Math की language में
# इसे हम कहते हैं m।
#
# अब starting में,
# जब घंटे 0 थे,
# तो कमाई भी 0 थी।
#
# इसे हम कहते हैं
# starting point,
# और math में इसे बोलते हैं c।
#
# अब मान लीजिए,
# कमाई को हम y कहते हैं
# और काम किए गए घंटे को x।
#
# तो हमारा equation बन जाता है:
#
# y = 50x + 0
#
# और इसी equation को
# short में लिखा जाता है —
#
# y = mx + c
#
# यही है
# Linear Equation का formula।
#
# बहुत बढ़िया 🎉
# आपने खुद से
# Linear Regression का
# math formula discover कर लिया।
#
# अब इस formula की मदद से
# आप किसी भी घंटे की कमाई
# आसानी से calculate कर सकते हैं।

# %% [markdown]
# ---
# 🗣️ Line (जब formula discover हो जाए)
#
# “यहाँ तक अगर सब clear है,
# तो आप already
# AI की language समझने लगे हो।”
#
# “अब सवाल ये नहीं है कि
# formula क्या है…
# सवाल ये है —
# machine ये formula खुद कैसे निकालती है?”

# %% [markdown]
# ---
# 🗣️ Trust Line (Soft + Natural)
#
# “अगर ये आपको बिना डर के समझ आ गया,
# तो यकीन मानिए —
# AI आपके level से बाहर नहीं है।”

# %% [markdown]
# ---
# 🗣️ Trust Line
#
# “अब जो आने वाला है,
# वो नया नहीं है —
# बस वही काम है
# जो आप अभी कर चुके हैं,
# सिर्फ machine के through।”

# %% [markdown]
# ---

# %% [markdown]
# अब बिल्कुल यही same काम
# हम Machine Learning में करने वाले हैं।
#
# जो काम हमने अभी तक
# manually prediction करके
# और math का formula discover करके किया,
# अब वही काम
# हम Machine Learning की Python libraries से करवाएँगे।
#
# यानि अब
# हम खुद calculate नहीं करेंगे,
# बल्कि machine को data देंगे
# और machine खुद सीखकर बताएगी।
#
# अब हम ये देखेंगे कि
# क्या machine
# same data table को use करके
# इस problem को solve कर पाती है या नहीं।
#
# और सबसे interesting बात —
# क्या machine
# खुद से formula discover कर पाती है?
# यानि क्या machine भी
# y = mx + c तक पहुँच पाती है?
#
# तो अगले step में,
# हम Python code चलाकर देखेंगे कि
# Machine Learning कैसे
# data से सीखती है,
# prediction करती है,
# और हमारा काम आसान बना देती है।

# %% [markdown]
# ---

# %% [markdown]
# 🗣️ Comment Prompt (Very High Response)
#
# “अब एक छोटा सा सवाल —
# अगर कमाई हर घंटे ₹50 नहीं,
# कभी ₹30, कभी ₹80 बढ़े…
# तो क्या Linear Regression चलेगी?”
#
# “Comment में सिर्फ लिखिए —
# ✔ Yes या ❌ No
# और क्यों।”
#
# ---

# %% [markdown]
# अब आप सोच रहे होंगे —
# “ठीक है, अब तो
# Machine Learning library
# problem solve कर देगी,
# लेकिन real life में
# हम इसे model की तरह
# use कैसे करेंगे?”
#
# जैसे ChatGPT में होता है —
# एक window खुलती है,
# हम उसमें कुछ type करते हैं,
# और तुरंत answer मिल जाता है।
#
# तो आगे हम
# यही सब सीखने वाले हैं।
#
# हम सीखेंगे —
#
# Machine Learning model कैसे बनाते हैं
#
# उसे save कैसे करते हैं
#
# और बाद में reuse कैसे करते हैं
#
# और high level पर ये भी समझेंगे
# कि model को server पर deploy कैसे किया जाता है।
#
# अब ध्यान दीजिए,
# Machine Learning model बनाने के
# कुछ pre-defined steps होते हैं।
#
# 🧠 Machine Learning Model Banane ke Steps
#
# Step 1️⃣
# सबसे पहले data लेते हैं
# और उसे clean करते हैं।
# मतलब —
# अगर data में
# null values हैं,
# तो या तो उन्हें remove करते हैं
# या फिर average value से replace करते हैं।
#
# Step 2️⃣
# Data को graph पर plot करते हैं,
# ताकि pattern समझ में आए
# और ये decide कर सकें
# कि कौन-सी technique
# इस problem के लिए best रहेगी।
#
# Step 3️⃣
# अब data को
# दो parts में split करते हैं —
# एक training के लिए
# और दूसरा testing के लिए।
#
# Step 4️⃣
# Training data की मदद से
# Machine Learning model को
# train करते हैं।
#
# Step 5️⃣
# अब model के
# metrics check करते हैं,
# ताकि पता चले
# model सही सीख रहा है या नहीं।
#
# अब हम Original कमाई और Predicted कमाई निकालते हैं और उन्हें एक ही table में रखते हैं, ताकि हम evaluation metrics को manually calculate कर सकें।
# हालाँकि जब हम model को train करते हैं, तो machine learning model ये सभी metrics हमें automatically दे देता है।
#
# लेकिन आपको अच्छी तरह समझाने के लिए, हम इन्हें manual तरीके से भी calculate करेंगे, ताकि आपको साफ़-साफ़ समझ आ सके कि machine learning model इन metrics को internally कैसे calculate करता है।
#
#
# Step 6️⃣
# अगर metrics बताते हैं
# कि model अच्छा perform कर रहा है,
# तो हम इस trained model को
# save कर लेते हैं,
# ताकि बार-बार training न करनी पड़े।
#
# Step 7️⃣
# अब सीखते हैं
# saved model को
# load कैसे करें
# और उससे prediction कैसे लें।
#
# Step 8️⃣
# और आखिर में,
# देखेंगे कि
# real world में
# Machine Learning model को
# server पर deploy कैसे किया जाता है।
#
# अब हम trained ML model की pickle या joblib file और model को load करने वाली script को server पर upload करके deployment process को follow कर सकते हैं।
# इस तरह वही trained model reuse किया जा सकता है और वह हमें fastest possible response देगा।
#
# हालाँकि, इस session में हम actual deployment को cover नहीं कर रहे हैं।
# इसे हम किसी और video में detail में cover करेंगे, नहीं तो यह video बहुत ज़्यादा lengthy हो जाएगी।

# %% [markdown]
# ---

# %% [markdown]
# अब मैं कुछ examples लेकर समझाता हूँ कि linear regression कब और किस तरह के data के लिए सही काम करता है, और किन situations में यह अच्छा काम नहीं करता।

# %% [markdown]
# ## 📌 Linear Regression कहाँ काम करता है और कहाँ नहीं – Examples
#
# ---
#
# ### ❌ Example : जहाँ Linear Regression काम नहीं करता
#
# अब एक **गाड़ी (Car / Truck)** का example लेते हैं।
#
# जब हम किसी गाड़ी को **accelerate** करते हैं:
# - समय (Time) बढ़ने पर
# - गाड़ी की **Speed बढ़ती ज़रूर है**,
# - लेकिन **हर second speed बराबर मात्रा में नहीं बढ़ती**।
#
# शुरुआत में speed धीरे बढ़ती है,
# फिर तेज़ी से बढ़ती है,
# और बाद में फिर slow हो जाती है।
#
# ---
#
# ### 📊 Graph से समझते हैं
# अब अगर हम:
# - X-axis पर **Time**
# - Y-axis पर **Speed**
#
# लेकर graph plot करें, तो आप देखेंगे कि:
#
# 👉 **Time के मुकाबले Speed बढ़ने की दर सीधी रेखा (Straight Line) नहीं बनाती**,
# बल्कि एक **Curve** जैसा pattern बनता है।
#
# ---
#
# ### 🚫 Conclusion
# क्योंकि यहाँ relationship **linear नहीं है**, इसलिए:
# - ❌ **Linear Regression यहाँ सही choice नहीं है**
# - ✔ यहाँ हमें **कोई और model** (जैसे Polynomial Regression) use करना पड़ेगा
#
# 👉 इन models को हम **किसी और video में detail में समझेंगे**,
# नहीं तो यह vidio बहुत लंबा हो जाएगा।

# %% [markdown]
# ### ✅ Example: Year और Crop Production (फसल उत्पादन)
#
# अब **Year (साल)** और **Crop Production (फसल उत्पादन)** के बीच relation को समझते हैं।
#
# मान लीजिए:
# - X-axis → **Year (1997, 2000, 2002, …)**
# - Y-axis → **Crop Production (टन में)**
#
# ---
#
# ### 📉 जब Linear Regression काम नहीं करेगा ❌
#
# अगर:
# - किसी साल बारिश कम हो गई 🌧️
# - किसी साल drought / flood आ गया
# - soil की fertility घट गई
# - या pest attack हो गया
#
# तो:
# - Production कभी ज़्यादा बढ़ेगा
# - कभी अचानक घट जाएगा
#
# Graph में:
# - Line सीधी नहीं बनेगी
# - बल्कि **उतार-चढ़ाव (zig-zag / curve)** दिखेगा
#
# 👉 ऐसे data पर ❌ **Linear Regression सही prediction नहीं देगा**
#
# ---
#
# ### 🧠 Conclusion
# - **Year vs Crop Production**
#   - ✔ Linear Regression → जब trend smooth और लगभग straight हो
#   - ❌ Linear Regression → जब data में मौसम, प्राकृतिक कारण और अचानक बदलाव हों
#
# 👉 ऐसे cases में हमें:
# - **Polynomial Regression**
# - **Time Series Models**
# - या **Advanced ML models**
#
# use करने पड़ते हैं, जिनको हम आगे detail में समझेंगे।

# %% [markdown]
# ## ✅ Example: House Price Prediction
# ### (Living Area in Sq.ft vs House Price)
#
# अब एक **classic और best example** लेते हैं जहाँ **Linear Regression बहुत अच्छे से काम करता है**।
#
# ---
#
# ### 🏠 Problem Statement
# हमें घर की **कीमत (House Price)** predict करनी है,
# based on घर का **Living Area (Square Feet में)**।
#
# ---
#
# ### 📊 Variables
# - **X-axis (Independent Variable)** → Living Area (sq.ft)
# - **Y-axis (Dependent Variable)** → House Price (₹ / ₹ लाख)
#
# ---
#
# ### 📈 Data का Behaviour
# आमतौर पर:
# - जैसे-जैसे **घर का area बढ़ता है**
# - वैसे-वैसे **घर की कीमत भी बढ़ती है**
#
# उदाहरण:
# - 500 sq.ft → ₹25 लाख
# - 1000 sq.ft → ₹50 लाख
# - 1500 sq.ft → ₹75 लाख
#
# 👉 Area और Price के बीच **लगभग सीधा (linear) relation** होता है।
#
# ---
#
# ### 📉 Graph से समझें
# जब हम इस data को graph पर plot करते हैं:
# - Points एक **सीधी रेखा (Straight Line)** के आसपास आते हैं
# - Trend साफ़ दिखाई देता है
#
# 👉 इसलिए यहाँ **Linear Regression best choice** है।
#
# ---
#
# ### 🧠 Linear Regression Model क्या सीखेगा?
# Model यह सीखेगा:
# \[
# \text{House Price} = m \times (\text{Area}) + c
# \]
#
# जहाँ:
# - **m** → प्रति sq.ft कीमत (price per sq.ft)
# - **c** → base price (fixed cost)
#
# ---
#
# ### ✅ Conclusion
# - ✔ Living Area और House Price के बीच relation **linear** है
# - ✔ Data smooth और predictable है
# - ✔ इसलिए **Linear Regression यहाँ सही काम करता है**
#
# 👉 यही कारण है कि **house price prediction**
# Linear Regression का सबसे popular example माना जाता है।
#
# ---
#
# ### ⚠️ Note (Real Life)
# अगर हम factors जोड़ दें जैसे:
# - Location
# - Number of rooms
# - Age of house
#
# तो:
# - Simple Linear Regression → **Multiple Linear Regression** बन जाता है
# (जिसे हम आगे सीखेंगे)

# %% [markdown]
# ---

# %% [markdown]
# ---------------------------------------
# असली ज़िंदगी में AI के उपयोग - REAL-LIFE AI USE CASES
# ---------------------------------------
# **1️⃣ सैलरी का अनुमान (Salary Prediction)**
#
# * अनुभव (Experience) → सैलरी
# * पुराने कर्मचारियों का डेटा देखकर
#   भविष्य की सैलरी का अंदाज़ा लगाया जाता है
#
# **2️⃣ घर की कीमत का अनुमान (House Price Prediction)**
#
# * एरिया (Area) → कीमत
# * ज़्यादा एरिया होने पर
#   आमतौर पर कीमत भी ज़्यादा होती है
#
# **3️⃣ बिक्री का अनुमान (Sales Forecast)**
#
# * महीने → बिक्री
# * कंपनी अगले महीने की
#   प्लानिंग इसी आधार पर करती है
#
# **4️⃣ छात्रों के अंकों का अनुमान (Student Marks Prediction)**
#
# * पढ़ाई के घंटे → अंक
# * टीचर्स कमजोर छात्रों को
#   पहचान पाते हैं
#
# **5️⃣ बिज़नेस की ग्रोथ**
#
# * समय → कमाई (Revenue)
# * निवेशक सही फैसले ले पाते हैं
#
# **हर जगह कहानी एक ही है:**
# **पुराना डेटा → पैटर्न → भविष्य का अनुमान**

# %% [markdown]
# ## Regression कब इस्तेमाल करें – सही तरीका
#
# ### छोटा जवाब - Short Answer
#
# Regression तब सबसे अच्छा काम करती है
# जब **बदलाव की दर (rate of change) स्थिर हो**
#
# या **लगभग स्थिर हो**।
#
# या **हर स्टेप पर बराबर बढ़ोतरी**।
#
# या **ग्राफ सीधी रेखा जैसा हो**।
#
#
# **उदाहरण:**
# हर घंटे ₹50 बढ़ रहा है
# → यहाँ Linear Regression सबसे सही है
#
#
# ### 3. जब लक्ष्य अनुमान या ट्रेंड जानना हो
#
# * भविष्य की वैल्यू चाहिए
# * बिल्कुल सटीक नियम नहीं, बल्कि सबसे अच्छा अनुमान चाहिए
#
# ---
#
# ## Regression कब नहीं इस्तेमाल करनी चाहिए ❌
#
# ### 1. जब रिश्ता सीधी रेखा जैसा न हो
#
# * घुमावदार (curve), U-शेप, या बहुत टेढ़ा-मेढ़ा डेटा
#
# → Linear Regression गलत होगी
# → Non-linear मॉडल चाहिए
#
# ---
#
# ### 2. जब डेटा पूरी तरह रैंडम हो
#
# * लॉटरी नंबर
# * पासा (डाइस) फेंकना
# * सिर्फ़ किस्मत पर आधारित चीज़ें
#
# → Regression बेकार अनुमान (prediction) देगी
#
# ---
#
# ### 3. जब नियम पहले से तय हो
#
# * उम्र < 18 → अनुमति नहीं - (Not allowed)
# * अंक ≥ 40 → पास
#
# → यहाँ If–Else लॉजिक लगेगा
# → Regression की ज़रूरत नहीं
#
# ---
#
# ### 4. जब डेटा सिर्फ़ कैटेगरी में हो
#
# * हाँ / नहीं - Yes / No
# * लाल / नीला / हरा - Red / Blue / Green
#
# → Classification मॉडल चाहिए - अगले वीडियो में सीखेंगे
# → Regression नहीं
#
# ---
#
# ## आसान Best-Practice नियम
#
# * सीधा ट्रेंड → Regression
# * घुमावदार ट्रेंड → दूसरे मॉडल
# * कोई पैटर्न नहीं → ML की ज़रूरत नहीं
# * तय नियम → लॉजिक, ML नहीं
#
# ---
#
# ## AI से संबंध
#
# AI भी यही करती है:
#
# * डेटा देखती है
# * उसमें पैटर्न ढूँढती है
# * नियम या फ़ॉर्मूला बनाती है
# * उसी से अनुमान लगाती है
#
# अगर **पैटर्न ही नहीं है**,
# तो **AI भी कुछ नहीं कर सकती**।

# %% [markdown]
# ---------------------------------------
# BEGINNER FAQs
# ---------------------------------------
#
# ❓ **क्या मुझे मैथ्स बहुत ज़्यादा स्ट्रॉन्ग होनी चाहिए?**
# ❌ नहीं।
# लॉजिक और सही समझ होना ही काफ़ी है।
#
# ❓ **क्या Linear Regression बहुत मुश्किल टॉपिक है?**
# ❌ नहीं।
# नाम भारी लगता है, लेकिन आइडिया बहुत आसान है।
#
# ❓ **क्या मैं AI सीख सकता हूँ?**
# ✅ बिल्कुल।
# आप तो पहले ही शुरुआत कर चुके हैं।
#
# ❓ **क्या हर prediction बिल्कुल सही होता है?**
# ❌ नहीं।
# यह एक अंदाज़ा (approximation) होता है, पक्का जवाब नहीं।
#
# ❓ **ML में सबसे पहले यही टॉपिक क्यों पढ़ाया जाता है?**
# ✅ क्योंकि यही पूरी मशीन लर्निंग की नींव है।
#
# ---
#
# ### हमेशा याद रखने वाली बात (FOREVER)
#
# **Linear Regression =**
# पुराने डेटा को देखकर
# भविष्य का अंदाज़ा लगाना
#
# ❌ कभी रट्टा मत लगाइए:
#
# * फ़ॉर्मूले
# * परिभाषाएँ
# * मुश्किल मैथ्स
#
# ---
#
# ### बस एक तस्वीर दिमाग में रखिए 🧠
#
# **डॉट्स + सीधी लाइन + आगे का पॉइंट**
#
# ---
#
# **“अगर तुम Linear Regression समझ गए,
# तो AI अब तुम्हारे लिए दूर का सपना नहीं रहा।”**
