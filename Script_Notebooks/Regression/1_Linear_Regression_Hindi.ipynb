# %% [markdown]
# <a href="https://colab.research.google.com/github/AI-Ki-Pathshala/AI-ML-tutorials/blob/main/Script_Notebooks/Regression/1_Linear_Regression_Hindi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---------------------------------------
# PART 1: Pure Math – Real Life Example
# ---------------------------------------
#
# Sochiye aap ek chai ki dukaan chala rahe ho ☕
# Aap notice karte ho:
#
# | Ghanta | Kamai |
# |--------|-------|
# | 0      | ₹0    |
# | 1      | ₹50   |
# | 2      | ₹100  |
# | 3      | ₹150  |
# | 4      | ?     |
#
#
# Manual Solve (Bina Formula)
#
# **Farak nikaalo:**
# - 100 − 50 = 50
# - 150 − 100 = 50
#
# **Observation:**
# Har ghante ₹50 badh rahe hain
#
# **Calculation:**
# 150 + 50 = **200**
#
# **Answer:**
# 4 ghante ki kamai = **₹200**
#
# ---------------------------------------
# Ab Pattern ko Formula mein badalte hain
# ---------------------------------------
#
# | Ghanta (x) | Kamai (y) | Rate of Change (m) | Starting Point (c) |
# |------------|-----------|-------------------|--------------------|
# | 0          | 0         | 50                | 0                  |
# | 1          | 50        | 50                | 0                  |
# | 2          | 100       | 50                | 0                  |
# | 3          | 150       | 50                | 0                  |
# | 4          | ?         | 50                | 0                  |
#
# **Meaning:**
# - m = 50 (har ghante ki kamai)
# - c = 0 (0 ghante par kamai 0)
#
# **Formula discover hui:**
# y = mx + c
# y = 50x + 0
#
# **Prediction:**
# y = 50 × 4 = **200**
#
# ---------------------------------------
# AI bhi exactly yahi karti hai
# ---------------------------------------
#
# - AI data dekhti hai
# - Data ka **pattern** nikaalti hai
# - Pattern se **rule / formula discover** karti hai
# - Us formula ka use karke **future value predict** karti hai
#
# 👉 Bas farq itna hai:
# Hum ye kaam **dimaag se** kar rahe hain,
# AI ye kaam **computer se** karti hai.

# %% [markdown]
# ---------------------------------------
# PART 2: CREATE GRAPH FROM MATH
# (USING PYTHON LIBRARIES)
# ---------------------------------------
#
# Ab hum wahi kahani aankhon se dekhna chahte hain 👀
# (Graph sirf picture hai — maths ka dar khatam karne ke liye)
#
# Python se simple graph (sirf dikhane ke liye)

# %%
import matplotlib.pyplot as plt

# Time (hours)
x = [1, 2, 3, 4]

# Money earned
y = [50, 100, 150, 200]

plt.scatter(x, y)
plt.plot(x, y)
plt.xlabel("Time (hours)")
plt.ylabel("Money (₹)")
plt.title("Time vs Money")
plt.show()

# %% [markdown]
# Ab graph ko kahani ki tarah samjho
#
# X-axis (neeche) → Time (ghante)
#
# Y-axis (side) → Paisa (₹)
#
# Dots (●) → Real data points
# (1 ghanta = ₹50, 2 ghante = ₹100…)
#
# Straight line kyun bani?
#
# Kyuki:
#
# Har bar time thoda badha
#
# Paisa bhi almost same rate se badha
#
# Graph keh raha hai:
#
# “Main future ka andaza laga sakta hoon”
#
# Agar kal aap 5 ghante kaam karo —
# graph bolega:
# 👉 “Lagbhag ₹250 milega”
#
# ⚠️ Note:
#
# Aapko code ya graph yaad rakhne ki zarurat nahi
#
# Sirf meaning samajhna kaafi hai
#
# End line (as required):
# “If you can read this graph, you understand the concept visually.”

# %% [markdown]
# ---------------------------------------
# PART 3: PURE PYTHON LOGIC (NO AI / ML)
# ---------------------------------------
#
# Ab wahi cheez normal Python logic se karte hain
# (No AI, no machine learning)
#
# Simple idea:
#
# “Average badlav nikal kar future guess karna”

# %%
# Past data
time = [1, 2, 3, 4]
money = [50, 100, 150, 200]

# Har ghante kitna paisa badh raha hai
increase_per_hour = []

for i in range(1, len(time)):
    change = money[i] - money[i-1]
    increase_per_hour.append(change)

average_increase = sum(increase_per_hour) / len(increase_per_hour)

# Future prediction
future_time = 5
predicted_money = average_increase * future_time

print(predicted_money)

# %% [markdown]
# Line-by-line bachchon jaise samjho
#
# time → input data
#
# money → output data
#
# Loop → har step ka difference
#
# Average → ek common rule
#
# Multiply → future ka guess
#
# Yani:
# Input → Process → Output
#
# Bilkul maths + graph jaisa hi
# Bas ab computer se karwaya
#
# 🎉 Agar yahan tak samajh aa gaya —
# toh aap Python se darne layak hi nahi ho
#
# End line (as required):
# “If you understand this Python logic, you are ready for AI.”

# %% [markdown]
# ---------------------------------------
# PART 4: AI + MACHINE LEARNING CODING
# ---------------------------------------
#
# Ab magic nahi, automation aata hai 🤖
#
# Machine kya karta hai?
#
# Data leta hai
#
# Khud rule seekhta hai
#
# Future ke answers deta hai
#
# Simple ML code (sirf concept ke liye)

# %%
from sklearn.linear_model import LinearRegression

# Training data
X = [[1], [2], [3], [4]]
y = [50, 100, 150, 200]

model = LinearRegression()
model.fit(X, y)

# Prediction
print(model.predict([[5]]))

# %% [markdown]
# Human language mein explanation
#
# model.fit() →
# Machine ne pichla data dekh kar relation seekh liya
#
# predict() →
# Machine ne future ka jawab diya
#
# ⚠️ Important:
#
# Machine bhi wahi kaam kar rahi hai
#
# Jo aap Part 1–3 mein khud kar chuke ho
#
# Sirf difference:
#
# Machine fast hai, tired nahi hoti 😄
#
# End line (as required):
# “This is enough AI knowledge for beginners.”

# %% [markdown]
# ---------------------------------------
# PART 5: REAL-LIFE AI USE CASES
# ---------------------------------------
# 1️⃣ Salary Prediction
#
# Experience → Salary
#
# Past employees ka data → future salary guess
#
# 2️⃣ House Price Prediction
#
# Area → Price
#
# Zyada area → zyada price (mostly)
#
# 3️⃣ Sales Forecast
#
# Months → Sales
#
# Company next month ki planning karti hai
#
# 4️⃣ Student Marks Prediction
#
# Study hours → Marks
#
# Teachers weak students identify karte hain
#
# 5️⃣ Business Growth
#
# Time → Revenue
#
# Investors decision lete hain
#
# Har jagah same kahani:
#
# Past data → pattern → future estimate

# %% [markdown]
# ## When to Use Regression – Best Practice
#
# ### Short Answer
# Regression tab best kaam karti hai
# jab **rate of change constant ho**
# ya **near to constant ho**.
#
# ---
#
# ## When Regression is a GOOD Choice ✅
#
# ### 1. Rate of change constant ho
# - Har step par same increase
# - Straight line trend
#
# **Example:**
# Har ghante ₹50 badh raha hai
# → Linear Regression best
#
# ---
#
# ### 2. Rate of change near to constant ho
# - Kabhi thoda zyada, kabhi thoda kam
# - Overall trend straight ho
#
# **Example:**
# ₹48, ₹52, ₹49, ₹51
# → Regression average rule nikaal leti hai
#
# ---
#
# ### 3. Goal prediction ya trend ho
# - Future value chahiye
# - Exact rule nahi, best-fit chahiye
#
# ---
#
# ## When Regression should NOT be used ❌
#
# ### 1. Relationship straight line nahi hai
# - Curve, U-shape, zig-zag data
#
# → Linear regression galat
# → Non-linear models chahiye
#
# ---
#
# ### 2. Data random hai
# - Lottery numbers
# - Dice roll
# - Pure chance
#
# → Regression bekaar prediction karegi
#
# ---
#
# ### 3. Rule pehle se fixed hai
# - Age < 18 → Not allowed
# - Marks ≥ 40 → Pass
#
# → If–else logic
# → Regression ki zarurat nahi
#
# ---
#
# ### 4. Data sirf category hai
# - Yes / No
# - Red / Blue / Green
#
# → Classification models
# → Regression nahi
#
# ---
#
# ## Simple Best-Practice Rule
#
# - Straight trend → Regression
# - Curve trend → Other models
# - No pattern → No ML
# - Fixed rule → Logic, not ML
#
# ---
#
# ## AI Connection
#
# AI bhi:
# - Data dekhti hai
# - Pattern dhoondti hai
# - Rule / formula discover karti hai
# - Us rule se prediction karti hai
#
# Agar pattern hi nahi hai,
# to AI bhi kuch nahi kar sakti.

# %% [markdown]
# ------------------------
# BAD - Real life meaning:
# ------------------------
# Gaadi accelerate kar rahi hai (speed har second zyada tez badh rahi hai).
#
# | Time (seconds) | Speed (km/h) |
# |----------------|-------------|
# | 1              | 2           |
# | 2              | 8           |
# | 3              | 18          |
# | 4              | 32          |
# | 5              | 50          |
# | 6              | 72          |

# %%
import matplotlib.pyplot as plt

time = [1, 2, 3, 4, 5, 6]
speed = [2, 8, 18, 32, 50, 72]

plt.scatter(time, speed)
plt.plot(time, speed)
plt.xlabel("Time (seconds)")
plt.ylabel("Speed (km/h)")
plt.title("Speed vs Time (Acceleration – Not Linear)")
plt.show()

# %% [markdown]
# ❗ Why Linear Regression is NOT Good Here
#
# Speed ka increase constant nahi hai
#
# Rate of change har second badh raha hai
#
# Graph straight line nahi banata

# %% [markdown]
# ---------------------------------------
# PART 6: BEGINNER FAQs + CONFIDENCE BOOST
# ---------------------------------------
# ❓ Kya mujhe maths strong honi chahiye?
#
# ❌ Nahi. Logic aur understanding enough hai.
#
# ❓ Kya Linear Regression tough topic hai?
#
# ❌ Nahi. Naam heavy hai, idea simple.
#
# ❓ Kya main AI seekh sakta hoon?
#
# ✅ Bilkul. Aap already start kar chuke ho.
#
# ❓ Kya har prediction perfect hota hai?
#
# ❌ Nahi. Ye approximation hota hai.
#
# ❓ Pehla ML topic yahi kyun hota hai?
#
# ✅ Kyunki ye foundation hai.
#
# Yaad rakhne wali baat (FOREVER)
#
# Linear Regression = Past dekh kar future ka andaza
#
# Jo kabhi ratta mat lagana
#
# ❌ Formulas
# ❌ Definitions
# ❌ Complex maths
#
# Ek mental picture rakho
#
# 🧠 Dots + Straight Line + Future Point
#
# Final confidence sentence 💪
#
# “Agar tum Linear Regression samajh gaye,
# AI tumhare liye ab door ka sapna nahi raha.”
